# %% [markdown]
# ## Praca domowa - regresja
#
# Twoim zadaniem jest przewidywanie jakości czerwonego wina na podstawie jego właściwości (kwasowość, pH, zawartość alkoholu, chlorków itd.)
#
# - Tagetem predykcji jest kolumna <strong>"quality"</strong>
# - "quality" przyjmuje pięć wartości: 3, 4, 5, 6, 7, 8. Możliwe, że Twoje rozwiązanie będzie miało lepszy wynik jeśli będziesz zaokrąglać wyniki swojej predykcji
# - Jaki wynik jest dobry? Każdy poniżej MSE 0.5 na zbiorze testowym jest całkiem niezły. Mi udało się zejść do 0.31
# - Śmiało można dodawać importy, szczególnie warto sobie przejrzeć co jest w sklearn.linear_model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import Lasso, BayesianRidge, LassoLars, TweedieRegressor, Ridge, LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Przygotowanie datasetu
#
# Parę wskazówek:
# - Czy wszystkie dane są Ci potrzebne?
# - Jak rozkładają się dane na boxplotach?
# - Jaka jest korelacja pomiędzy featurami a targetem?
# - Czy przyda się normalizacja/standaryzacja danych?

# %%
data = pd.read_csv('./data/winequality-red.csv', delimiter=',')
data.dataframeName = 'winequality-red.csv'
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## 2. Regresja
# W tej części trzeba zbudować model oraz ocenić jego predykcję za pomocą MSE. Polecam wypróbować pare modeli, poczytać dokumentację, pobawić się parametrami. Powodzenia!
